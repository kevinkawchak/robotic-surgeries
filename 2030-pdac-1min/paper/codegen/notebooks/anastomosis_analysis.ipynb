# %% [markdown]
# # 3 Anastomosis Outcome Analysis (v0.6.0)

# %%
import pandas as pd

df = pd.read_csv('../data/iterations/run_00000_L4_anastomosis.csv')
print(df)
print()
print('PJ ring rmse:', df.loc[df.anastomosis_id == 'pancreaticojejunostomy', 'ring_tension_rmse_n'].iloc[0])
print('HJ ring rmse:', df.loc[df.anastomosis_id == 'hepaticojejunostomy', 'ring_tension_rmse_n'].iloc[0])
print('GJ ring rmse:', df.loc[df.anastomosis_id == 'gastrojejunostomy', 'ring_tension_rmse_n'].iloc[0])
